# %%
import json
import pandas as pd
import numpy as np
import geopy
from geopy.distance import geodesic

import folium  #needed for interactive map
from folium.plugins import HeatMap

# %%
competitors = pd.read_csv('market_research_raw.csv')
competitors
# Out:
#                                      name  \
# 0                 Harley-Davidson® Toluca
# 1                    Pontiac Gmc Tollocan
# 2                    German Centre Mexico
# 3                               Mazda Ral
# 4    Distrubuidora Chevrolet S.A. de C.V.
# ..                                    ...
# 260                        Autos La Libre
# 261                               Autofin
# 262                       seminuevos vema
# 263                          Autos compra
# 264                        Alberto Nissan
#
#                                      formatted_address  \
# 0    Carretera Toluca - México Km 43.5 Ortíz Rubio,...
# 1    CD de México Toluca KM 46, Ocoyoacac, Col Juár...
# 2    Av Sta Fe 170, Santa Fe, Zedec Sta Fé, Álvaro ...
# 3    Periferico Sur 6611, San Juan Tepepan, Xochimi...
# 4    D, Anillo Perif. 6611, Santa María Tepepan, Xo...
# ..                                                 ...
# 260     Pueblo Quieto, 04739 Mexico City, CDMX, Mexico
# 261  Local 121C, Anillo Perif. 5550, Pedregal de Ca...
# 262  Periferico Sur 4809 arenal tepepan deleg, Aren...
# 263  Arenal Tepepan, Tlalpan, 14610 Ciudad de Méxic...
# 264  Av. Insurgentes Sur 3195, Insurgentes Cuicuilc...
#
#                                            website  rating        lat  \
# 0                  http://hogtolucachapter.com.mx/     4.5  19.285820
# 1              http://www.buickgmctollocan.com.mx/     4.2  19.283495
# 2                      http://www.germancentre.mx/     4.5  19.366759
# 3    https://www.mazda.mx/distribuidores/mazda-ral     4.3  19.281704
# 4                                              NaN     4.0  19.281916
# ..                                             ...     ...        ...
# 260                                            NaN     NaN  19.300610
# 261                                            NaN     3.5  19.306293
# 262              http://www.seminuevosvema.com.mx/     5.0  19.285523
# 263                                            NaN     NaN  19.285334
# 264                                            NaN     NaN  19.308368
#
#            lng
# 0   -99.455125
# 1   -99.472292
# 2   -99.260581
# 3   -99.135790
# 4   -99.137145
# ..         ...
# 260 -99.160390
# 261 -99.165580
# 262 -99.148746
# 263 -99.148273
# 264 -99.187237
#
# [265 rows x 6 columns]

# %%
#Ver las agencias en un mapa
kavak_shw = [(19.278630, -99.484617), (19.424953, -99.166439), 
             (19.483682, -99.133187), (19.377280, -99.254569), (19.283918, -99.176300)]
shw_names = ['Lerma', 'Florencia', 'Fortuna', 'Santa_Fe', 'Tlalpan']
folium_map = folium.Map(location=[19.4, -99.3],
                        zoom_start=11,tiles="OpenStreetMap")

#Add showroom locations
for showroom in kavak_shw:
    marker = folium.Marker(location=showroom,radius=9)
    marker.add_to(folium_map)

# %%
comp_coor = list(zip(competitors['lat'], competitors['lng'], competitors['name']))

for comp in comp_coor:
    marker = folium.Marker(location=comp[:2],
                           popup=comp[2][:5],
                           icon=folium.Icon(color='green'))
    marker.add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Obtener Distancias a Cada Showroom

for i in range(5):
    competitors['distance_'+shw_names[i]] = pd.Series([geodesic(kavak_shw[i],
                                                                x[:2]).km for x in comp_coor])
competitors
# Out:
#                                      name  \
# 0                 Harley-Davidson® Toluca
# 1                    Pontiac Gmc Tollocan
# 2                    German Centre Mexico
# 3                               Mazda Ral
# 4    Distrubuidora Chevrolet S.A. de C.V.
# ..                                    ...
# 260                        Autos La Libre
# 261                               Autofin
# 262                       seminuevos vema
# 263                          Autos compra
# 264                        Alberto Nissan
#
#                                      formatted_address  \
# 0    Carretera Toluca - México Km 43.5 Ortíz Rubio,...
# 1    CD de México Toluca KM 46, Ocoyoacac, Col Juár...
# 2    Av Sta Fe 170, Santa Fe, Zedec Sta Fé, Álvaro ...
# 3    Periferico Sur 6611, San Juan Tepepan, Xochimi...
# 4    D, Anillo Perif. 6611, Santa María Tepepan, Xo...
# ..                                                 ...
# 260     Pueblo Quieto, 04739 Mexico City, CDMX, Mexico
# 261  Local 121C, Anillo Perif. 5550, Pedregal de Ca...
# 262  Periferico Sur 4809 arenal tepepan deleg, Aren...
# 263  Arenal Tepepan, Tlalpan, 14610 Ciudad de Méxic...
# 264  Av. Insurgentes Sur 3195, Insurgentes Cuicuilc...
#
#                                            website  rating        lat  \
# 0                  http://hogtolucachapter.com.mx/     4.5  19.285820
# 1              http://www.buickgmctollocan.com.mx/     4.2  19.283495
# 2                      http://www.germancentre.mx/     4.5  19.366759
# 3    https://www.mazda.mx/distribuidores/mazda-ral     4.3  19.281704
# 4                                              NaN     4.0  19.281916
# ..                                             ...     ...        ...
# 260                                            NaN     NaN  19.300610
# 261                                            NaN     3.5  19.306293
# 262              http://www.seminuevosvema.com.mx/     5.0  19.285523
# 263                                            NaN     NaN  19.285334
# 264                                            NaN     NaN  19.308368
#
#            lng  distance_Lerma  distance_Florencia  distance_Fortuna  \
# 0   -99.455125        3.200536           34.017490         40.291936
# 1   -99.472292        1.403003           35.747246         41.952631
# 2   -99.260581       25.484455           11.801941         18.615181
# 3   -99.135790       36.668361           16.180811         22.359967
# 4   -99.137145       36.526097           16.130090         22.338753
# ..         ...             ...                 ...               ...
# 260 -99.160390       34.165809           13.778972         20.465919
# 261 -99.165580       33.672444           13.135554         19.929021
# 262 -99.148746       35.312744           15.545935         21.996357
# 263 -99.148273       35.362077           15.572781         22.013639
# 264 -99.187237       31.429324           13.089231         20.220138
#
#      distance_Santa_Fe  distance_Tlalpan
# 0            23.380484         29.308466
# 1            25.124104         31.112415
# 2             1.324905         12.748886
# 3            16.362325          4.265169
# 4            16.238701          4.121614
# ..                 ...               ...
# 260          13.036977          2.492145
# 261          12.213946          2.721051
# 262          15.060651          2.901680
# 263          15.111551          2.950171
# 264          10.404113          2.940477
#
# [265 rows x 11 columns]

# %%
competitors.to_csv('market_research_clean.csv')
